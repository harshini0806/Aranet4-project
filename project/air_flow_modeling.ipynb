# %% [markdown]
# Air containing 0.06% CO2 is pumped into a room whose volume is 8000 ft^3. The air pumped in at a rate of 2000 ft^3 /min, and the circulated air is then pumped out at the same rate. If there is an initial concentration of 0.2% CO2 in the room, determine the subsequent amount in the room at time t. What is the concentration of CO2 at 10 minutes? What is the steady state, or equilibrium, concentration of CO2?

# %% [markdown]
# To solve this problem, we can set up a differential equation based on the rate of change of CO2 concentration in the room.
#
# Let $C(t)$ be the concentration of CO2 in the room at time $t$ (expressed as a decimal, so 0.2% would be 0.002). The volume of the room is $V = 8000$ ft³, and the rate of air flow into and out of the room is $Q = 2000$ ft³/min. The concentration of CO2 in the incoming air is $C_{\text{in}} = 0.06\% = 0.0006$.
#
# The rate of change of the amount of CO2 in the room is given by the difference between the rate at which CO2 is added to the room and the rate at which it is removed:
#
# $$
# \frac{d(CV)}{dt} = Q C_{\text{in}} - Q C(t)
# $$
#
# Since the volume $V$ is constant, we can simplify this to:
#
# $$
# V \frac{dC}{dt} = Q (C_{\text{in}} - C(t))
# $$
#
# $$
# \frac{dC}{dt} = \frac{Q}{V} (C_{\text{in}} - C(t))
# $$
#
# Now we can solve this first-order linear differential equation. The general solution is:
#
# $$
# C(t) = C_{\text{in}} + (C_0 - C_{\text{in}}) e^{-\frac{Q}{V}t}
# $$
#
# where $C_0$ is the initial concentration of CO2 in the room (0.2% or 0.002).
#
# To find the concentration of CO2 at 10 minutes, we can substitute $t = 10$, $Q = 2000$, $V = 8000$, $C_{\text{in}} = 0.0006$, and $C_0 = 0.002$ into the equation:
#
# $$
# C(10) = 0.0006 + (0.002 - 0.0006) e^{-\frac{2000}{8000} \times 10}
# $$
#
# $$
# C(10) = 0.0006 + 0.0014 e^{-2.5}
# $$
#
# $$
# C(10) \approx 0.0006 + 0.0014 \times 0.08208
# $$
#
# $$
# C(10) \approx 0.0006 + 0.000115
# $$
#
# $$
# C(10) \approx 0.000715
# $$
#
# So, the concentration of CO2 at 10 minutes is approximately 0.0715%.
#
# The steady-state, or equilibrium, concentration of CO2 occurs when the rate of change of CO2 concentration is zero, i.e., when $\frac{dC}{dt} = 0$. From the differential equation, this happens when $C(t) = C_{\text{in}}$. Therefore, the equilibrium concentration of CO2 is 0.06%.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
V = 8000  # Volume of the room in ft^3
Q = 2000  # Air flow rate in ft^3/min
C_in = 0.0006  # Concentration of CO2 in incoming air (0.06%)
C_0 = 0.002  # Initial concentration of CO2 in the room (0.2%)

# Time range
t = np.linspace(0, 10, 100)  # Time range from 0 to 10 minutes

# Solve the differential equation
C = C_in + (C_0 - C_in) * np.exp(-Q/V * t)

# Plot the concentration of CO2 over time
plt.plot(t, C)
plt.xlabel('Time (minutes)')
plt.ylabel('CO2 Concentration')
plt.title('Concentration of CO2 in the Room over Time')
plt.show()

# Concentration of CO2 at 10 minutes
C_10 = C[np.where(t == 10)]
print(f"The concentration of CO2 at 10 minutes is approximately {C_10[0] * 100:.4f}%")

# Steady state concentration of CO2
C_steady_state = C_in
print(f"The steady state concentration of CO2 is approximately {C_steady_state * 100:.4f}%")
# Out:
# The concentration of CO2 at 30 minutes is approximately 0.0715%
# The steady state concentration of CO2 is approximately 0.0600%

# %% [markdown]
# # CO2 in PPM
# Certainly! We can reframe the problem in terms of parts per million (ppm) instead of percent. Let's start by expressing the concentration of CO2 in the room and the concentration of CO2 in the incoming air in ppm.
#
# To solve this problem, we can set up a differential equation based on the rate of change of CO2 concentration in the room.
#
# Let $C(t)$ be the concentration of CO2 in the room at time $t$ in ppm. The volume of the room is $V = 8000$ ft³, and the rate of air flow into and out of the room is $Q = 2000$ ft³/min. The concentration of CO2 in the incoming air is $C_{\text{in}} = 600$ ppm.
#
# The rate of change of the amount of CO2 in the room is given by the difference between the rate at which CO2 is added to the room and the rate at which it is removed:
#
# $$
# \frac{d(CV)}{dt} = Q C_{\text{in}} - Q C(t)
# $$
#
# Since the volume $V$ is constant, we can simplify this to:
#
# $$
# V \frac{dC}{dt} = Q (C_{\text{in}} - C(t))
# $$
#
# $$
# \frac{dC}{dt} = \frac{Q}{V} (C_{\text{in}} - C(t))
# $$
#
# Now we can solve this first-order linear differential equation. The general solution is:
#
# $$
# C(t) = C_{\text{in}} + (C_0 - C_{\text{in}}) e^{-\frac{Q}{V}t}
# $$
#
# where $C_0$ is the initial concentration of CO2 in the room (0.2% or 2000 ppm).
#
# To find the concentration of CO2 at 10 minutes, we can substitute $t = 10$, $Q = 2000$, $V = 8000$, $C_{\text{in}} = 600$, and $C_0 = 2000$ into the equation:
#
# $$
# C(10) = 600 + (2000 - 600) e^{-\frac{2000}{8000} \times 10}
# $$
#
# $$
# C(10) = 600 + 1400 e^{-2.5}
# $$
#
# $$
# C(10) \approx 600 + 1400 \times 0.08208
# $$
#
# $$
# C(10) \approx 600 + 115.312
# $$
#
# $$
# C(10) \approx 715.312
# $$
#
# So, the concentration of CO2 at 10 minutes is approximately 715.312 ppm.
#
# The steady-state, or equilibrium, concentration of CO2 occurs when the rate of change of CO2 concentration is zero, i.e., when $\frac{dC}{dt} = 0$. From the differential equation, this happens when $C(t) = C_{\text{in}}$. Therefore, the equilibrium concentration of CO2 is 600 ppm.

# %% [markdown]
# A quick query with copilot and chatgpt4 returns rough bounds of 150 to 600 PPM CO2 is produced on average per minute by a single person. Depending on if they are at rest or partaking in physical activity

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
V = 30*30*10  # Volume of the room in ft^3
Q = 15*17  # Air flow rate in ft^3/min (175 is an estimated amount) This might be too low, but 2000 is way to high.
            # 15 ft^3/min per person * 17 people is a rough estimate of the air flow rate
C_in = 150*17  # Concentration of CO2 in incoming air (150 co2/person) *(17 person)
C_0 = 600  # Initial concentration of CO2 in the room 

# Time range
t = np.linspace(0, 75, 750)  # Time range from 0 to 30 minutes

# Solve the differential equation
C = C_in + (C_0 - 0.5*C_in) * np.exp(-Q/V * t)

# Plot the concentration of CO2 over time
plt.plot(t, C)
plt.xlabel('Time (minutes)')
plt.ylabel('CO2 Concentration (PPM)')
plt.title('Concentration of CO2 in the Room over Time')
plt.show()

# Concentration of CO2 at 10 minutes
C_10 = C[np.where(t == 75)]
print(f"The concentration of CO2 at 75 minutes is approximately {C_10[0]:.4f} PPM")

# Steady state concentration of CO2
C_steady_state = C_in
print(f"The steady state concentration of CO2 is approximately {C_steady_state:.4f} PPM")
# Out:
# The concentration of CO2 at 75 minutes is approximately 2469.3827 PPM
# The steady state concentration of CO2 is approximately 2550.0000 PPM

# %%
30*30*12
# Out:
# 10800

# %% [markdown]
# ## Stochastic Model

# %%
import numpy as np
import matplotlib.pyplot as plt

# # Parameters
# V = 8000  # Volume of the room in ft³
# Q = 2000  # Airflow rate in ft³/min
# C_in = 600  # Incoming CO2 concentration in ppm
# C0 = 2000  # Initial CO2 concentration in ppm

# Constants
V = 30*30*10  # Volume of the room in ft^3
Q = 15*17  # Air flow rate in ft^3/min (175 is an estimated amount) This might be too low, but 2000 is way to high.
            # 15 ft^3/min per person * 17 people is a rough estimate of the air flow rate
C_in = 150*17  # Concentration of CO2 in incoming air (150 co2/person) *(17 person)
C0 = 1000  # Initial concentration of CO2 in the room 
sigma = 50  # Intensity of the noise
dt = 1  # Time step in minutes
T = 75  # Total time in minutes
N = int(T / dt)  # Number of steps
t = np.linspace(0, T, N)  # Time vector

# Euler-Maruyama method
C = np.zeros(N)
C[0] = C0
for i in range(1, N):
    dW = np.random.normal(0, np.sqrt(dt))  # Increment of Wiener process
    C[i] = C[i-1] + (Q/V) * (C_in - C[i-1]) * dt + sigma * dW

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(t, C, label='Stochastic CO2 Concentration')
plt.axhline(y=C_in, color='r', linestyle='--', label='Equilibrium Concentration')
plt.xlabel('Time (minutes)')
plt.ylabel('CO2 Concentration (ppm)')
plt.title('Stochastic Model of CO2 Concentration in a Room')
plt.legend()
plt.show()

# %%
import pandas as pd
aranet4_path = "./datasets/aranet4.csv"

aranet4 = pd.read_csv(aranet4_path)
aranet4.head()
# Out:
#    Carbon dioxide(ppm)  Temperature(°F)  Relative humidity(%)  \
# 0                 1014             77.8                  47.0
# 1                  884             78.5                  46.0
# 2                  914             79.7                  43.0
# 3                  906             79.7                  42.0
# 4                  896             79.3                  41.0
#
#    Atmospheric pressure(hPa)        Date      Time             Datetime
# 0                     1007.3  01/12/2024  16:08:15  2024-01-12 16:08:15
# 1                     1007.3  01/12/2024  16:09:15  2024-01-12 16:09:15
# 2                     1007.4  01/12/2024  16:10:15  2024-01-12 16:10:15
# 3                     1007.2  01/12/2024  16:11:15  2024-01-12 16:11:15
# 4                     1007.3  01/12/2024  16:12:15  2024-01-12 16:12:15

# %%
aranet4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97857 entries, 0 to 97856
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Carbon dioxide(ppm)        97857 non-null  int64
#  1   Temperature(°F)            97857 non-null  float64
#  2   Relative humidity(%)       97804 non-null  float64
#  3   Atmospheric pressure(hPa)  95335 non-null  float64
#  4   Date                       97857 non-null  object
#  5   Time                       97857 non-null  object
#  6   Datetime                   97857 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.2+ MB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert the Datetime column to datetime
aranet4['Datetime'] = pd.to_datetime(aranet4['Datetime'])

# Filter the data for the specified time range
start_time = pd.to_datetime('2024-03-18 12:30:15')
end_time = pd.to_datetime('2024-03-18 13:45:15')
filtered_data = aranet4[(aranet4['Datetime'] >= start_time) & (aranet4['Datetime'] <= end_time)]

# Plot the CO2 levels
# Plotting
plt.figure(figsize=(12, 6 ))
plt.plot(filtered_data['Datetime'], filtered_data['Carbon dioxide(ppm)'])
plt.xlabel('Time')
plt.ylabel('CO2 Levels')
plt.title('CO2 Levels from 12:30:15 to 1:45:15 on 03-18-2024')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Overlay of Aranet4, Stochastic, and ODE Model for CO2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Stochastic model parameters and data generation as provided before
# Constants for the stochastic model
V = 30*30*10  # Volume of the room in ft^3
Q = 15*17  # Air flow rate in ft^3/min
C_in = 150*17  # Concentration of CO2 in incoming air
C0 = 900  # Initial concentration of CO2 in the room
sigma = 50  # Intensity of the noise
dt = 1  # Time step in minutes
T = 75  # Total time in minutes
N = int(T / dt)  # Number of steps
t = np.linspace(0, T, N)  # Time vector

# Euler-Maruyama method for the stochastic model
C = np.zeros(N)
C[0] = C0
for i in range(1, N):
    dW = np.random.normal(0, np.sqrt(dt))  # Increment of Wiener process
    C[i] = C[i-1] + (Q/V) * (C_in - C[i-1]) * dt + sigma * dW

# Assuming 'aranet4' is a DataFrame with your actual minute-to-minute CO2 readings
# Read in your actual 'aranet4' data here
# aranet4 = pd.read_csv('path_to_your_data.csv')  # Replace with the actual data loading code

# Ensure 'Datetime' column is in datetime format and rounded to the nearest minute
aranet4['Datetime'] = pd.to_datetime(aranet4['Datetime']).dt.round('min')

# Filter the data for the specified 75-minute interval
start_time = pd.to_datetime('2024-03-18 12:30')
end_time = start_time + pd.Timedelta(minutes=75)
filtered_data = aranet4[(aranet4['Datetime'] >= start_time) & (aranet4['Datetime'] <= end_time)]

# Plot the stochastic CO2 concentration and the Aranet4 CO2 levels
plt.figure(figsize=(10, 6))

# Plot stochastic CO2 concentration
plt.plot(t, C, label='Stochastic CO2 Concentration')

# Plot equilibrium concentration
plt.axhline(y=C_in, color='r', linestyle='--', label='Equilibrium Concentration')

# Plot Aranet4 CO2 levels, aligning the time axis to the model
filtered_data['Minutes Since Start'] = (filtered_data['Datetime'] - start_time).dt.total_seconds() / 60
plt.plot(filtered_data['Minutes Since Start'], filtered_data['Carbon dioxide(ppm)'], label='Aranet4 CO2 Levels')

# Format the plot
plt.xlabel('Time (minutes)')
plt.ylabel('CO2 Concentration (ppm)')
plt.title('Stochastic Model vs. Aranet4 CO2 Levels Over 75 Minutes')
plt.legend()
plt.xlim(0, 75)  # Limit x-axis to 75 minutes
plt.grid(True)  # Add a grid for easier reading
plt.show()
# Out:
# C:\Users\Corey Dearing\AppData\Local\Temp\ipykernel_59172\1519168843.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Minutes Since Start'] = (filtered_data['Datetime'] - start_time).dt.total_seconds() / 60

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Constants for the deterministic model
V_det = 30*30*10  # Volume of the room in ft^3
Q_det = 20*17  # Air flow rate in ft^3/min
C_in_det = 100*17  # Concentration of CO2 in incoming air
C_0_det = 989  # Initial concentration of CO2 in the room 

# Time range for the deterministic model
t_det = np.linspace(0, 75, 750)  # Time range from 0 to 75 minutes

# Solve the differential equation for the deterministic model
C_det = C_in_det + (C_0_det - C_in_det) * np.exp(-Q_det/V_det * t_det)

# Constants for the stochastic model
V_sto = 30*30*10  # Volume of the room in ft^3
Q_sto = 20*17  # Air flow rate in ft^3/min
C_in_sto = 100*17  # Concentration of CO2 in incoming air
C_0_sto = 989  # Initial concentration of CO2 in the room (different from the deterministic model)
sigma = 40  # Intensity of the noise
dt = 1  # Time step in minutes
T = 75  # Total time in minutes
N = int(T / dt)  # Number of steps

# Euler-Maruyama method for the stochastic model
t_sto = np.linspace(0, T, N)  # Time vector
C_sto = np.zeros(N)
C_sto[0] = C_0_sto
for i in range(1, N):
    dW = np.random.normal(0, np.sqrt(dt))  # Increment of Wiener process
    C_sto[i] = C_sto[i-1] + (Q_sto/V_sto) * (C_in_sto - C_sto[i-1]) * dt + sigma * dW

# Assume 'aranet4' is the DataFrame with your actual minute-to-minute CO2 readings
# Read in your actual 'aranet4' data here
# aranet4 = pd.read_csv('path_to_your_data.csv')  # Replace with the actual data loading code

# Ensure 'Datetime' column is in datetime format and rounded to the nearest minute
aranet4['Datetime'] = pd.to_datetime(aranet4['Datetime']).dt.round('min')

# Filter the data for the specified 75-minute interval
start_time = pd.to_datetime('2024-03-18 12:30')
end_time = start_time + pd.Timedelta(minutes=75)
# Filter the data for the specified 75-minute interval and create a copy to avoid the SettingWithCopyWarning
filtered_data = aranet4[(aranet4['Datetime'] >= start_time) & (aranet4['Datetime'] <= end_time)].copy()

# Calculate the minutes since the start for the Aranet4 data
filtered_data['Minutes Since Start'] = (filtered_data['Datetime'] - start_time).dt.total_seconds() / 60

# Start plotting
plt.figure(figsize=(12, 6))

# Plot the deterministic model's CO2 concentration
plt.plot(t_det, C_det, label='Deterministic Model CO2 Concentration', color='green')

# Plot the stochastic model's CO2 concentration
plt.plot(t_sto, C_sto, label='Stochastic Model CO2 Concentration', color='blue')

# Plot the equilibrium concentration
plt.axhline(y=C_in_sto, color='r', linestyle='--', label='Equilibrium Concentration')

# Plot the Aranet4 CO2 levels, aligning the time axis to the models
filtered_data['Minutes Since Start'] = (filtered_data['Datetime'] - start_time).dt.total_seconds() / 60
plt.plot(filtered_data['Minutes Since Start'], filtered_data['Carbon dioxide(ppm)'], label='Aranet4 CO2 Levels', color='orange')

# Format the plot
plt.xlabel('Time (minutes)')
plt.ylabel('CO2 Concentration (ppm)')
plt.title('Comparison of CO2 Concentration Models Over 75 Minutes')
plt.legend()
plt.grid(True)  # Add a grid for easier reading
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Corey Dearing\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# For the stochastic model, I'm going to try and add a random variable based on if the doors randomly begin as open, semi-open, closed, and use the stats we get from the data we collect to vary the amount of CO2 that stays in the room. Once we get some descriptive statistics we can run simulations partition the data based on the final 75 conditions. We can possibly use a poisson distribution to treat a change in the door being open or closed in a calculation as a rare event. We will probably find that once both doors are closed, they remain closed until the end of the session.

# %%
filtered_data.head()
# Out:
#        Carbon dioxide(ppm)  Temperature(°F)  Relative humidity(%)  \
# 94762                  989             73.8                  37.0
# 94763                  994             73.8                  37.0
# 94764                 1002             73.8                  37.0
# 94765                 1023             73.8                  37.0
# 94766                 1006             73.7                  38.0
#
#        Atmospheric pressure(hPa)        Date      Time            Datetime  \
# 94762                     1007.3  03/18/2024  12:30:25 2024-03-18 12:30:00
# 94763                     1007.3  03/18/2024  12:31:25 2024-03-18 12:31:00
# 94764                     1007.4  03/18/2024  12:32:25 2024-03-18 12:32:00
# 94765                     1007.5  03/18/2024  12:33:25 2024-03-18 12:33:00
# 94766                     1007.5  03/18/2024  12:34:25 2024-03-18 12:34:00
#
#        Minutes Since Start
# 94762                  0.0
# 94763                  1.0
# 94764                  2.0
# ...
